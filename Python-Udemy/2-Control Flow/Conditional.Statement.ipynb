# %% [markdown]
# ### Conditional Statement - (if, elif, else)

# %%
## if statement

age = 20
if age>18:
    print("You are allowed to vote for the election")
# Out:
# You are allowed to vote for the election

# %%
## if else statement
age = 12
if age>18:
    print("You are allowed to vote for the election")
else:
    print("You are not allowed to vite for the election")
# Out:
# You are not allowed to vite for the election

# %%
## if elif statement
age = 8
if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")
else:
    print("You are a adult now")
# Out:
# You are a child
# You are a child

# %%
age=int(input("Enter you age"))

print(age)
# Out:
# 33
